# %% [markdown]
# ## Aula 01

# %%
import pandas as pd

notas = pd.read_csv("ratings.csv")
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.shape
# Out:
# (100836, 4)

# %%
notas.columns = ["usuarioId", "filmeId", "nota", "momento"]
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas['nota']
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %%
notas['nota'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas['nota'].value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: nota, dtype: int64

# %%
print("Média das notas:", notas['nota'].mean())
print("Mediana das notas:", notas['nota'].median())
# Out:
# Média das notas: 3.501556983616962
# Mediana das notas: 3.5

# %%
notas.nota.head()
# Out:
# 0    4.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: nota, dtype: float64

# %%
notas.nota.plot(kind='hist')

# %%
print("Mediana das notas:", notas['nota'].median())
# Out:
# Mediana das notas: 3.5

# %%
notas.nota.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
import seaborn as sns

sns.boxplot(notas.nota)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Aula 02

# %%
filmes = pd.read_csv("movies.csv")
filmes.columns = ["filmeId", "titulo", "generos"]
filmes.head()
# Out:
#    filmeId  ...                                      generos
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas.query("filmeId == 1")
# Out:
#        usuarioId  filmeId  nota     momento
# 0              1        1   4.0   964982703
# 516            5        1   4.0   847434962
# 874            7        1   4.5  1106635946
# 1434          15        1   2.5  1510577970
# 1667          17        1   4.5  1305696483
# ...          ...      ...   ...         ...
# 97364        606        1   2.5  1349082950
# 98479        607        1   4.0   964744033
# 98666        608        1   2.5  1117408267
# 99497        609        1   3.0   847221025
# 99534        610        1   5.0  1479542900
#
# [215 rows x 4 columns]

# %%
notas.query("filmeId == 1").nota
# Out:
# 0        4.0
# 516      4.0
# 874      4.5
# 1434     2.5
# 1667     4.5
#         ...
# 97364    2.5
# 98479    4.0
# 98666    2.5
# 99497    3.0
# 99534    5.0
# Name: nota, Length: 215, dtype: float64

# %%
notas.query("filmeId == 1").nota.mean()
# Out:
# 3.9209302325581397

# %%
notas.query("filmeId == 2").nota.mean()
# Out:
# 3.4318181818181817

# %%
notas.groupby("filmeId")

# %%
notas.groupby("filmeId").mean()
# Out:
#           usuarioId      nota       momento
# filmeId
# 1        306.530233  3.920930  1.129835e+09
# 2        329.554545  3.431818  1.135805e+09
# 3        283.596154  3.259615  1.005110e+09
# 4        219.857143  2.357143  8.985789e+08
# 5        299.571429  3.071429  9.926643e+08
# ...             ...       ...           ...
# 193581   184.000000  4.000000  1.537109e+09
# 193583   184.000000  3.500000  1.537110e+09
# 193585   184.000000  3.500000  1.537110e+09
# 193587   184.000000  3.500000  1.537110e+09
# 193609   331.000000  4.000000  1.537158e+09
#
# [9724 rows x 3 columns]

# %%
medias_por_filme = notas.groupby("filmeId").mean().nota
medias_por_filme
# Out:
# filmeId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: nota, Length: 9724, dtype: float64

# %%
medias_por_filme.plot(kind="hist")

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5, 8))
sns.boxplot(y=medias_por_filme)

# %%
medias_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: nota, dtype: float64

# %%
sns.displot(medias_por_filme, bins=10)

# %%
plt.hist(medias_por_filme)
plt.title("Histograma das médias dos filmes")
# Out:
# Text(0.5, 1.0, 'Histograma das médias dos filmes')

# %% [markdown]
# ## Aula 03

# %%
tmdb = pd.read_csv("tmdb_5000_movies.csv")
tmdb.head()
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
# 3  250000000  ...       9106
# 4  260000000  ...       2124
#
# [5 rows x 20 columns]

# %%
tmdb.original_language.unique() # Categorica nominal
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
tmdb.budget.unique() # Quantitativa
# Out:
# array([237000000, 300000000, 245000000, 250000000, 260000000, 258000000,
#        280000000, 270000000, 200000000, 255000000, 225000000, 220000000,
#        380000000, 215000000, 180000000, 207000000, 209000000, 150000000,
#        210000000, 170000000, 190000000, 195000000, 105000000, 185000000,
#        175000000, 140000000, 176000003, 178000000, 145000000,  27000000,
#        165000000, 160000000,  15000000,  38000000, 155000000, 149000000,
#        144000000,  70000000, 100000000, 139000000, 135000000, 130000000,
#        137000000, 120000000, 132000000, 110000000, 125000000, 127500000,
#        127000000, 103000000,  65000000, 123000000, 115000000, 117000000,
#        113000000,  97250400, 116000000, 112000000,  93000000, 107000000,
#                0, 133000000, 108000000, 126000000,  90000000, 102000000,
#         80000000,  84000000,  99000000,  10000000,  98000000,  94000000,
#         85000000,  92000000,  95000000,  79000000,  75000000,  88000000,
# ...

# %%
tmdb["original_language"].value_counts()
# Out:
# en    4505
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# cn      12
# ko      11
# ru      11
# pt       9
# da       7
# sv       5
# fa       4
# nl       4
# he       3
# th       3
# ta       2
# ar       2
# ro       2
# id       2
# cs       2
# tr       1
# nb       1
# no       1
# sl       1
# el       1
# hu       1
# af       1
# ps       1
# ky       1
# pl       1
# xx       1
# te       1
# is       1
# vi       1
# Name: original_language, dtype: int64

# %%
tmdb["original_language"].value_counts().to_frame()
# Out:
#     original_language
# en               4505
# fr                 70
# es                 32
# zh                 27
# de                 27
# hi                 19
# ja                 16
# it                 14
# cn                 12
# ko                 11
# ru                 11
# pt                  9
# da                  7
# sv                  5
# fa                  4
# nl                  4
# he                  3
# th                  3
# ta                  2
# ar                  2
# ro                  2
# id                  2
# cs                  2
# tr                  1
# nb                  1
# no                  1
# sl                  1
# el                  1
# hu                  1
# af                  1
# ps                  1
# ky                  1
# pl                  1
# xx                  1
# te                  1
# is                  1
# vi                  1

# %%
contagem_de_lingua = tmdb["original_language"].value_counts().to_frame().reset_index()
contagem_de_lingua.columns = ["original_language", "total"]
contagem_de_lingua.head()
# Out:
#   original_language  total
# 0                en   4505
# 1                fr     70
# 2                es     32
# 3                zh     27
# 4                de     27

# %%
sns.barplot(x="original_language", y="total", data = contagem_de_lingua)

# %%
sns.catplot(x = "original_language", kind="count", data = tmdb)

# %%
plt.pie(contagem_de_lingua["total"], labels = contagem_de_lingua["original_language"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f69193454e0>,
# ...
#  [Text(-1.0791697536499925, 0.2130554923183512, 'en'),
#   Text(1.0355355017029462, -0.3710339940124459, 'fr'),
#   Text(1.0579676486019882, -0.3011718023181785, 'es'),
#   Text(1.0687996606645356, -0.26012936274741094, 'zh'),
#   Text(1.0773191105706255, -0.22222406260195313, 'de'),
#   Text(1.0835167978583342, -0.18971386021801853, 'hi'),
#   Text(1.0875756432724297, -0.16486121484618815, 'ja'),
#   Text(1.0906010773146022, -0.14348968659882622, 'it'),
#   Text(1.092883487371409, -0.12492270822755745, 'cn'),
#   Text(1.0946390911069936, -0.10846778425161549, 'ko'),
#   Text(1.0960865535188649, -0.09270527058984593, 'ru'),
#   Text(1.0972054830031333, -0.07835896928789601, 'pt'),
#   Text(1.097965443340663, -0.06687215586282344, 'da'),
#   Text(1.0984565010300316, -0.05825217030171998, 'sv'),
#   Text(1.0987803851616647, -0.0517847968421653, 'fa'),
#   Text(1.0990363161210686, -0.04603450713357274, 'nl'),
# ...

# %%
total_por_lingua = tmdb.original_language.value_counts()
total_geral = total_por_lingua.sum()
total_de_ingles = total_por_lingua.loc["en"]
total_do_resto = total_geral - total_de_ingles

print(total_de_ingles)
print(total_do_resto)
# Out:
# 4505
# 298

# %%
dados = {
    'lingua' : ['ingles', 'outros'],
    'total' : [total_de_ingles, total_do_resto]
}
dados
# Out:
# {'lingua': ['ingles', 'outros'], 'total': [4505, 298]}

# %%
dados = pd.DataFrame(dados)
dados
# Out:
#    lingua  total
# 0  ingles   4505
# 1  outros    298

# %%
sns.barplot(x = "lingua", y = "total", data = dados)

# %%
plt.pie(dados["total"], labels = dados["lingua"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f691926a4e0>,
# ...
#  [Text(-1.0791697536499925, 0.2130554923183512, 'ingles'),
#   Text(1.0791697511565306, -0.2130555049482467, 'outros')])

# %%
total_por_lingua_de_outros_filmes = tmdb.query("original_language != 'en'")["original_language"].value_counts()
total_por_lingua_de_outros_filmes
# Out:
# fr    70
# es    32
# zh    27
# de    27
# hi    19
# ja    16
# it    14
# cn    12
# ru    11
# ko    11
# pt     9
# da     7
# sv     5
# fa     4
# nl     4
# th     3
# he     3
# cs     2
# ar     2
# ro     2
# ta     2
# id     2
# hu     1
# te     1
# ky     1
# vi     1
# af     1
# xx     1
# el     1
# no     1
# tr     1
# is     1
# nb     1
# pl     1
# ps     1
# sl     1
# Name: original_language, dtype: int64

# %%
filmes_sem_lingua_original_em_ingles = tmdb.query("original_language != 'en'")
sns.catplot(x = "original_language", kind="count", data = filmes_sem_lingua_original_em_ingles)

# %% [markdown]
# # Aula 05

# %%
filmes_sem_lingua_original_em_ingles = tmdb.query("original_language != 'en'")
sns.catplot(x = "original_language", kind="count", data = filmes_sem_lingua_original_em_ingles, 
            aspect=2, 
            palette="GnBu_d",
            order=total_por_lingua_de_outros_filmes.index
            )

# %% [markdown]
# # Aula 06

# %%
filmes.head()
# Out:
#    filmeId  ...                                      generos
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
notas_do_toy_story = notas.query("filmeId==1")
notas_do_jumaji = notas.query("filmeId==2")

print(len(notas_do_toy_story), len(notas_do_jumaji))
# Out:
# 215 110

# %%
print("Nota média do Toy Story %.2f" % notas_do_toy_story.nota.mean())
print("Nota média do Jumaji %.2f" % notas_do_jumaji.nota.mean())
# Out:
# Nota média do Toy Story 3.92
# Nota média do Jumaji 3.43

# %%
# Out:
# Nota média do Jumaji 3.43

# %%
print("Mediana do Toy Story %.2f" % notas_do_toy_story.nota.median())
print("Mediana do Jumaji %.2f" % notas_do_jumaji.nota.median())
# Out:
# Mediana do Toy Story 4.00
# Mediana do Jumaji 3.50

# %%
import numpy as np

filme1 = np.append(
  np.array([2.5] * 10),
  np.array([3.5] * 10)
)

# %%
plt.boxplot([notas_do_toy_story.nota, notas_do_jumaji.nota])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f690f696dd8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f690f6a5828>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f690f6ad2e8>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f690f6a5f28>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f690f6a5128>,
# ...
#   <matplotlib.lines.Line2D at 0x7f690f6add68>]}

# %%
sns.boxplot(x = "filmeId", y = "nota", data = notas.query("filmeId in [1,2,3,4,5]"))

# %%
print(notas_do_toy_story.nota.std())
print(notas_do_jumaji.nota.std())
# Out:
# 0.8348591407114045
# 0.8817134921476455
